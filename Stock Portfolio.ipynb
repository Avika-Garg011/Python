# %% [markdown]
# In this Python project, we created

# %%
# Starting Portfolio balance is 800000
stock_portfolio = 800000
year_counter = 0

while stock_portfolio < 1000000:
    # Calculate annual investment income
    investment_income = stock_portfolio * 0.05   #5% interest rate
    
    # Add income to end of year portfolio balance
    stock_portfolio += investment_income
    
    # Add one each year 
    year_counter += 1

    print(f'At the end of the year {year_counter}: ' + f'My balance is ${round(stock_portfolio, 2)}')
# Out:
# At the end of the year 1: My balance is $840000.0
# At the end of the year 2: My balance is $882000.0
# At the end of the year 3: My balance is $926100.0
# At the end of the year 4: My balance is $972405.0
# At the end of the year 5: My balance is $1021025.25
